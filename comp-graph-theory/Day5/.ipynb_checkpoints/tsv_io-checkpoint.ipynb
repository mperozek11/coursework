# %%
import numpy as np
import scipy.sparse as spr
import matplotlib.pyplot as plt
import networkx as nx

# %%
wiki = nx.DiGraph()

# %%
total_lines_seen = 0
with open('/Users/maxperozek/CP341/Day4/wikispeedia_paths-and-graph/links.tsv') as f:
    while line:
        line = f.readline().strip()

        if total_lines_seen > 200:
            break
        total_lines_seen += 1
        if len(line) > 0 and line[0] != '#':
            u, v = line.split('\t')
            wiki.add_edge(u, v)

# %%
nx.draw(wiki)

# %%
small = nx.DiGraph()

# %%
small.add_edge('A','B')
small.add_edge('A','D')
small.add_edge('B','D')
small.add_edge('C','D')
small.add_edge('D','A')
small.add_edge('C','B')

# %%
nx.draw(small, with_labels=True)

# %%
# Networkx dependency issue
# nx.to_scipy_sparse_array(small).todense().T
adj = nx.to_scipy_sparse_array(small).T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <cell line: 3>()
#       1 # Networkx dependency issue
#       2 # nx.to_scipy_sparse_array(small).todense().T
# ----> 3 adj = nx.to_scipy_sparse_array(small).T
#
# File ~/opt/anaconda3/envs/comp_gr_thy/lib/python3.9/site-packages/networkx/convert_matrix.py:907, in to_scipy_sparse_array(G, nodelist, dtype, weight, format)
#     904     row, col, data = [], [], []
#     906 if G.is_directed():
# --> 907     A = sp.sparse.coo_array((data, (row, col)), shape=(nlen, nlen), dtype=dtype)
#     908 else:
#     909     # symmetrize matrix
#     910     d = data + data
#
# AttributeError: module 'scipy.sparse' has no attribute 'coo_array'

# %%
adj.sum(0)

# %%
S = (adj / adj.sum(0))

# %%
goog = .85 * S + .15 * ((1/4) * np.ones_like(S)) # 4 because there are 4 total websites

# %%
current = 1/4 * np.ones(4)

# %%
for i in range(200):
    current = goog.dot(current)
    print(current)

# %%
import scipy

# %%
scipy.__version__
# Out:
# '1.7.3'

# %%
nx.__version__
# Out:
# '2.7.1'
