# %%
import matplotlib.pyplot as plt
from scipy.ndimage import convolve
from skimage.io import imread
import numpy as np

# %%
# vertical edges
# horizontal edges
# any edge

# %%
plt.rcParams['figure.figsize'] = 12, 10

# %%
# image = imread("/Users/maxperozek/Desktop/worksheet2.jpg")[:,:,0]
# image = imread("/Users/maxperozek/Desktop/IMG_6905.jpeg")[:,:,0]

image = imread("/Users/maxperozek/Desktop/IMG_2369.jpeg")[:,:,0]

# %%
plt.matshow(image)

# %%
vert_filter = [
    [0,1,0],
    [0,1,0],
    [0,1,0]
]

vert1_filter = [
    [1,0,-1],
    [1,0,-1],
    [1,0,-1]
]


horiz_filter = [
    [-1,-1,-1],
    [0,0,0],
    [1,1,1]
]

edge_filter = [
    [1,0,1],
    [0,0,0],
    [1,0,1]
]

edge1_filter = [
    [-2,-1,0],
    [-1,0,1],
    [0,1,2]
]

good_filter = [
    [1,1,1],
    [1,-8,1],
    [1,1,1]
]

edge2_filter = np.matmul(vert1_filter,horiz_filter)

# %%
plt.matshow(convolve(image, horiz_filter))

# %%
plt.matshow(convolve(image, vert_filter))

# %%
plt.matshow(convolve(image, edge1_filter))

# %%
plt.matshow(convolve(image, good_filter))
